# %% [markdown]
# ## install tweepy

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Library

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream 
import pandas as pd
import csv

# %% [markdown]
# ## Api Key dan Token

# %%
access_token = "1456897593196171265-GpjXAmlBZIWlhXnBh8PRhyaePy78BP"
access_token_secret = "jD8y1qPhRNZv5irRKJgYoYMs7vj9PYPhy4XL43RhpceUB"
api_key = "eEiWUnz8qVGWOLQaRv0joVfrK"
api_key_secret = "10Xytw1lNJZbcn4kxaedIq2XaI6BXRP6PhXYvkPUOFZEscStN6"

# %% [markdown]
# ## Auth

# %%
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
search_key = "jokowi"

# %% [markdown]
# ## set CSV

# %%
csvFile = open(search_key+"4.csv","a+", newline="", encoding="utf-8")
csvWriter = csv.writer(csvFile)
c = []
i = []
u = []
t = []

for tweet in tweepy.Cursor(api.search_tweets,q=search_key + " -filter:retweets",count=1000,lang="id", until="2021-11-25").items(1000):
  print(tweet.created_at, tweet.id, tweet.user.name, tweet.text)
  c.append(tweet.created_at)
  i.append(tweet.id)
  u.append(tweet.user.name)
  t.append(tweet.text.encode("utf-8"))
  tweets = [tweet.created_at, tweet.id, tweet.user.name, tweet.text.encode("utf-8")]
  csvWriter.writerow(tweets)

dictTweets = {"waktu":c, "id":i, "username":u, "teks":t}
df = pd.DataFrame(dictTweets, columns=["Waktu", "id", "username", "teks"])
df
# Out:
# 2021-11-24 23:59:58+00:00 1463658683427012613 Wawaa @egik_prabowo @kikasyafii @jokowi @Puspen_TNI @DivHumas_Polri kamu tau kan kenapa dia memilih untuk tidak melerai? wkw
# 2021-11-24 23:59:30+00:00 1463658567387410434 Leah Smith Keberhasilan Pemerintahan Presiden Jokowi
#
# Jokowi Bangun Nusantara https://t.co/2zE5FO5tJD
# 2021-11-24 23:59:23+00:00 1463658537855250438 Mang Rese @detikcom Jokowi malah minta tiga periode
# 2021-11-24 23:59:19+00:00 1463658522315423744 Marquita Jones Keberhasilan Pemerintahan Presiden Jokowi
#
# Jokowi Bangun Nusantara https://t.co/ETUgu04oEI
# 2021-11-24 23:58:59+00:00 1463658438131478530 Anas @tvOneNews Sepertinya Pak Jokowi sedang mengkritik Bapak Presiden.
# 2021-11-24 23:58:42+00:00 1463658366903853057 Motivator Qur'ani ™ Ternyata Jokowi Yang Akan Mencari Lokasi Balap Formula E https://t.co/R7Xp45UXXm https://t.co/oxqinD0qqq
# ...

# %%
pip show tweepy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: tweepy

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Work! Izin test SKB pake alesan apa yaa. Blm punya jatah cuti 😭
# OJK Ungkap Banyak Investor Berminat Akuisisi Bank di RI https://t.co/9ZHWTqResS
# Hasil Indonesia Open: Marcus/Kevin Maju ke Perempat Final https://t.co/29DArGtHwl
# work! maaf untuk salary technical writer range berapa ya skrg2 ini? trimakasih
# Work! Eh demi ini aku seharian gaada kerjaan gapapa gak sih? Udah ngerjain sebagian cuma karna filenya kurang belum… https://t.co/O7gGmPXhn6
# Samsung Belum Beri Sinyal Pindahkan Produksi HP Vietnam ke RI https://t.co/eOyOiZEic2
# Keunggulan Xpander yang Tekuk Avanza dan Veloz di GIIAS https://t.co/IFr1mPZlgl
# Work! Kira2 gimana ya? Aku bingung bgt sih https://t.co/RyH5CGq0im
# Menko Airlangga Soal 3 Poin Keputusan MK Soal UU Ciptaker https://t.co/OI1H1eCO7C
# Buruh Jabar Demo di Gedung Sate, Protes Aturan UMP Buah UU Ciptaker https://t.co/P1f2oF369N
# Sempat Ngebut, IHSG Kehabisan Bensin! Finis Hijau Tipis... https://t.co/MkMRHXrqCD
# ...
